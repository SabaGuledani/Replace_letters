# %%
#aq araferi shecvalo darune ubralod

georgian_to_english = {
    "ა": "a",
    "ბ": "b",
    "გ": "g",
    "დ": "d",
    "ე": "e",
    "ვ": "v",
    "ზ": "z",
    "თ": "T",
    "ი": "i",
    "კ": "k",
    "ლ": "l",
    "მ": "m",
    "ნ": "n",
    "ო": "o",
    "პ": "p",
    "ჟ": "J",
    "რ": "r",
    "ს": "s",
    "ტ": "t",
    "უ": "u",
    "ფ": "f",
    "ქ": "q",
    "ღ": "R",
    "ყ": "y",
    "შ": "S",
    "ჩ": "C",
    "ც": "c",
    "ძ": "Z",
    "წ": "w",
    "ჭ": "W",
    "ხ": "x",
    "ჯ": "j",
    "ჰ": "h",
}


english_to_georgian = {
    "a": "ა",
    "S": "შ",
    "C": "ჩ",
    "R": "ღ",
    "Z": "ძ",
    "b": "ბ",
    "g": "გ",
    "d": "დ",
    "q":"ქ",
    "e": "ე",
    "v": "ვ",
    "z": "ზ",
    "T": "თ",
    "t":"ტ",
    "i": "ი",
    "k": "კ",
    "l": "ლ",
    "m": "მ",
    "n": "ნ",
    "o": "ო",
    "p": "პ",
    "r": "რ",
    "s": "ს",
    "u": "უ",
    "f": "ფ",
    "y": "ყ",
    "c": "ც",
    "w": "წ",
    "x": "ხ",
    "W": "ჭ",
    "j": "ჯ",
    "h": "ჰ",
}

def targmna(text, to="ka"):
    
    nacarqeqia_replaced = text.replace('მთავარი გმირი:', 'ნაცარქექია: ')
    naCarqeqia_replaced = text.replace('naCarqeqia','nacarqeqia')

    if to == "eng":
        for letter in georgian_to_english:
            nacarqeqia_replaced = nacarqeqia_replaced.replace(letter, georgian_to_english[letter])
    else: 
        for letter in english_to_georgian:
            nacarqeqia_replaced = nacarqeqia_replaced.replace(letter, english_to_georgian[letter])
    # print(nacarqeqia_replaced)
    lines = nacarqeqia_replaced.splitlines()

    # Iterate through the lines
    for line in lines:
        print(line)

# %% [markdown]
# # amis qveda blokshi chasvi teqsti

# %%
text = '''
ნაცარქექია: მარტო რას აკეთებ ტყეში, დახმარება ხომ არ გინდა?
უცნობი ბავშვი: დიახ,  მე უბრალოდ ვემალები სხვა ბავშვებს. ყოველთვის დამცინიან და ცუდ სიტყვებს მეძახიან.
ნაცარქექია: მე სკოლა დიდი ხნის დამთავრებული მაქვს, მეც ბევრი რამ შემემთხვა, მომიყევი რა გგჭირვებია, იქნებ დახმარება შევძლო.

უცნობი ბავშვი: ჩვენ, სოკოებს მასწავლებლები და ბავშვები ზედაც არ გვიყურებენ. თავს გარიყულად და დასჯილად ვგრძნობ.
ნაცარქექია: მიამბე აბა რა დაგმართნია და გეტყვი როგორ უნდა მოიქცე.~ პირველი
უცნობი ბავშვი: დღეს სკოლაში რომ მივედი ჩემი კლასელი კუთხეში იჯდა და ტიროდა. სხვა ბავშვებმა დაუწყეს დაცინვა და სათამაშოებს ესროდნენ. მას ყველა დასცინოდა მე კი არ ვიცოდი რა მეღონა. შენ რას გააკეთებდი ჩემს მაგივრად?

	ნაცარქექია: ეს სწორი პასუხია! ადამიანის დამცირება იმის გამო, რომ შენგან განსხვავებულია, დაუშვებელია!
	


უცნობი ბავშვი: ბოლო გაკვეთილზეც დავიბენი, რადგან არ ვიცოდი როგორ მოვქცეულიყავი.
~ მეოთხე
უცნობი ბავშვი: ჩემი ისტორიის მასწავლებელი სოკოებს უკანა მერხებზე გვსვამს, წინ დასხდომა არ შეგვიძლია და ყოველთვის გვეუბნება, რომ სოკოები დამნაშავეები არიან. ეს ნორმალურია? ამ დროს როგორ მოვიქცე ხოლმე?
- უთხრა ეს ამბავი დამრიგებელს / დირექტორს რათა მიიღონ შესაბამისი ზომები
	ნაცარქექია: პასუხი სწორია!
- დაემორჩილო მას, რადგან მასწავლებელი ყოველთვის მართალია
	ნაცარქექია: არავინაა ყოველთვის მართალი, არასდროს შეიზღუდო თავი და დასვი კითხვა- რატომ? პასუხი არასწორია, თავიდან სცადე...
	=> მეოთხე
- არ მიაქციო ყურადღება
	ნაცარქექია: პასუხი არასწორია, თავიდან სცადე...
	=> მეოთხე
	
ნაცარქექია: ყოჩაღ! შენ უკვე შეგიძლია გაარჩიო რა არის ცუდი და რა კარგი საქციელი! 
ნაცარქექია: კარგად. მომავალ შეხვედრამდე!
=> ენდ
 


'''

# %% [markdown]
# # gaushvi qveda bloki
# ## tu ginda ro inglisuridan qartulze targmnos "eng" is nacvlad chawere ka

# %%
targmna(text, "eng")
# Out:
# nacarqeqia: marto ras akeTeb tyeSi, daxmareba xom ar ginda?
# ucnobi bavSvi: diax,  me ubralod vemalebi sxva bavSvebs. yovelTvis damcinian da cud sityvebs meZaxian.
# nacarqeqia: me skola didi xnis damTavrebuli maqvs, mec bevri ram SememTxva, momiyevi ra ggWirvebia, iqneb daxmareba SevZlo.
#
# ucnobi bavSvi: Cven, sokoebs maswavleblebi da bavSvebi zedac ar gviyureben. Tavs gariyulad da dasjilad vgrZnob.
# nacarqeqia: miambe aba ra dagmarTnia da getyvi rogor unda moiqce.~ pirveli
# ucnobi bavSvi: dRes skolaSi rom mivedi Cemi klaseli kuTxeSi ijda da tiroda. sxva bavSvebma dauwyes dacinva da saTamaSoebs esrodnen. mas yvela dascinoda me ki ar vicodi ra meRona. Sen ras gaakeTebdi Cems magivrad?
#
# - SevuerTdebodi danarCenebs da erTad davcinebdiT
# 	nacarqeqia: dacinva ar SeiZleba, kargi bavSvebi ki ase ar iqcevian. Tavidan scade...
# 	=> pirveli
#
# - yuradRebas ar mivaqcevdi
# 	nacarqeqia: adamians ar unda dascino, visac dascinian, unda daexmaro! Tavidan scade...
# 	=> pirveli
# ...

# %%
string = '''
ტბის ფერია: gamarjoba nacarqeqia.
ნაცარქექია: gamarjoba.
ტბის ფერია: mipasuxe kiTxvebze sworad da jadosnuri gragniliT dagajildoveb.
	ტბის ფერია: pasuxi sworia!
- daaignoreb xeebis CurCuls da koncentrirdebi sakuTar gzaze.
	ტბის ფერია: pasuxi arasworia!
	xeebis sruliad uaryofam SeiZleba wagarTvas potenciurad Rirebuli informacia. maSinac ki Tu zogierTi CurCuli mcdaria, maT SeiZleba hqondeT simarTlis niSnebi.
	scade xelaxla.
	=> mesame
ტბის ფერია: es codna da gragnili momavalSi aucileblad dagexmareba.

'''
lines = string.splitlines()


for line in lines:
    print(line)
# Out:
# ტბის ფერია: gamarjoba nacarqeqia.
# ნაცარქექია: gamarjoba.
# ტბის ფერია: mipasuxe kiTxvebze sworad da jadosnuri gragniliT dagajildoveb.
# ნაცარქექია: mzad var.
# ტბის ფერია: pirveli SekiTxva:
# ~ pirveli
# ტბის ფერია: nacarqeqia, molaparake Citisgan iReb idumal gzavnils, romelic gawvdis siaxleebsa da mosazrebebs msoflios Sesaxeb. rogor gaigeb aris Tu ara es Citi sando?
# - Seafaseb mis mier mowodebul mtkicebulebebs da daadastureb sxva wayraoebidan.
# 	ტბის ფერია: pasuxi sworia!
# - endobi molaparake Cits, radgan molaparake Citis sityvebs sibrZne unda hqondes.
# 	ტბის ფერია: samwuxarod pasuxi arasworia!
# 	Cven ar unda vivaraudoT, rom vinme aris mcodne an sando, maTi SesaZleblobebis safuZvelze da ara realuri mtkicebulebebiT. xolo molaparake frinvelebi sulac ar aris informaciis sando wyaro.
# 	axla ki Tavidan mipasuxe kiTxvaze.
# 	=> pirveli
# - ugulebelyob Citis Setyobinebas gadamowmebis gareSe.
# 	ტბის ფერია: samwuxarod pasuxi arasworia!
# ...

# %%
# Out:
# {'ა': 'a',
#  'ბ': 'b',
#  'გ': 'g',
#  'დ': 'd',
#  'ე': 'e',
#  'ვ': 'v',
#  'ზ': 'z',
#  'თ': 'T',
#  'ი': 'i',
#  'კ': 'k',
#  'ლ': 'l',
#  'მ': 'm',
#  'ნ': 'n',
#  'ო': 'o',
#  'პ': 'p',
#  'ჟ': 'J',
#  'რ': 'r',
#  'ს': 's',
#  'ტ': 't',
#  'უ': 'u',
#  'ფ': 'f',
#  'ქ': 'q',
#  'ღ': 'R',
#  'ყ': 'y',
#  'შ': 'S',
#  'ჩ': 'C',
#  'ც': 'C',
#  'ძ': 'Z',
#  'წ': 'w',
#  'ჭ': 'W',
#  'ხ': 'x',
#  'ჯ': 'j',
#  'ჰ': 'h'}

# %%
import numpy as np

A = np.array([[56.0,0.0,4.4,68.0],
              [1.2,104.0,52.0,8.0],
              [1.8,135.0,99.0,0.9]])

# %%
print(A)
# Out:
# [[ 56.    0.    4.4  68. ]
#  [  1.2 104.   52.    8. ]
#  [  1.8 135.   99.    0.9]]

# %%
cal = A.sum(0)
print(cal)
# Out:
# [ 59.  239.  155.4  76.9]

# %%
perc = A/cal

# %%
perc
# Out:
# array([[0.94915254, 0.        , 0.02831403, 0.88426528],
#        [0.02033898, 0.43514644, 0.33462033, 0.10403121],
#        [0.03050847, 0.56485356, 0.63706564, 0.01170351]])
